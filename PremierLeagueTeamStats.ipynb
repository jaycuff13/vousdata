# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#import CSV File 

matches = pd.read_csv("/Users/JordanCuff/Downloads/matches.csv")

# %%
#Anaylsis data using .head() function

matches.head()
# Out:
#    Unnamed: 0        date   time            comp        round  day venue  \
# 0           0  2022-08-05  20:00  Premier League  Matchweek 1  Fri  Away
# 1           1  2022-08-13  15:00  Premier League  Matchweek 2  Sat  Home
# 2           2  2022-08-20  17:30  Premier League  Matchweek 3  Sat  Away
# 3           3  2022-08-27  17:30  Premier League  Matchweek 4  Sat  Home
# 4           4  2022-08-31  19:30  Premier League  Matchweek 5  Wed  Home
#
#   result   gf   ga  ...  match report  notes    sh  sot  dist   fk   pk pkatt  \
# 0      W  2.0  0.0  ...  Match Report    NaN  10.0  2.0  14.6  1.0  0.0   0.0
# 1      W  4.0  2.0  ...  Match Report    NaN  19.0  7.0  13.0  0.0  0.0   0.0
# 2      W  3.0  0.0  ...  Match Report    NaN  14.0  6.0  14.8  0.0  0.0   0.0
# 3      W  2.0  1.0  ...  Match Report    NaN  22.0  8.0  15.5  1.0  0.0   0.0
# 4      W  2.0  1.0  ...  Match Report    NaN  22.0  8.0  16.3  1.0  0.0   0.0
#
#   season     team
# 0   2022  Arsenal
# 1   2022  Arsenal
# ...

# %%
#Getting total value counts of match results

matches['result'].value_counts()
# Out:
# W    404
# L    404
# D    244
# Name: result, dtype: int64

# %%
#Calculate total wins by team across all seasons 

matches['team'].value_counts() + matches[matches['result'] == 'W']['team'].value_counts(ascending=False)
# Out:
# Arsenal                     86
# Aston Villa                 71
# Bournemouth                 19
# Brentford                   70
# Brighton and Hove Albion    70
# Burnley                     45
# Chelsea                     79
# Crystal Palace              68
# Everton                     67
# Fulham                      20
# Leeds United                65
# Leicester City              72
# Liverpool                   86
# Manchester City             91
# Manchester United           76
# Newcastle United            74
# Norwich City                43
# Nottingham Forest           18
# Southampton                 65
# Tottenham Hotspur           84
# Watford                     44
# West Ham United             73
# Wolverhampton Wanderers     70
# Name: team, dtype: int64

# %%
matches['venue'].value_counts()
# Out:
# Away    526
# Home    526
# Name: venue, dtype: int64

# %%
#Calculation total home losses by each team 

matches['team'].value_counts() + matches[matches['result'] == 'L'][matches['venue'] == 'Home']['team'].value_counts()
# Out:
# /var/folders/z9/yx7qb12d66s57rbmx2llg5d40000gn/T/ipykernel_50826/3721064368.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   matches['team'].value_counts() + matches[matches['result'] == 'L'][matches['venue'] == 'Home']['team'].value_counts()
# Arsenal                     56
# Aston Villa                 63
# Bournemouth                 18
# Brentford                   63
# Brighton and Hove Albion    61
# Burnley                     46
# Chelsea                     56
# Crystal Palace              58
# Everton                     64
# Fulham                      17
# Leeds United                63
# Leicester City              61
# Liverpool                   53
# Manchester City             55
# Manchester United           57
# Newcastle United            58
# Norwich City                51
# Nottingham Forest           18
# Southampton                 62
# Tottenham Hotspur           60
# Watford                     53
# ...

# %%
#Calculation total home wins by each team 

matches['team'].value_counts() + matches[matches['result'] == 'W'][matches['venue'] == 'Home']['team'].value_counts()
# Out:
# /var/folders/z9/yx7qb12d66s57rbmx2llg5d40000gn/T/ipykernel_50826/3400992209.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   matches['team'].value_counts() + matches[matches['result'] == 'W'][matches['venue'] == 'Home']['team'].value_counts()
# Arsenal                     71
# Aston Villa                 63
# Bournemouth                 18
# Brentford                   63
# Brighton and Hove Albion    60
# Burnley                     43
# Chelsea                     64
# Crystal Palace              63
# Everton                     64
# Fulham                      18
# Leeds United                59
# Leicester City              65
# Liverpool                   72
# Manchester City             74
# Manchester United           66
# Newcastle United            66
# Norwich City                41
# Nottingham Forest           18
# Southampton                 60
# Tottenham Hotspur           72
# Watford                     40
# ...

# %%
#Horizontal Bar graph that calculates total wins both home and away by each team 

((matches[matches['result'] == 'W'][matches['venue'] == 'Home']['team'].value_counts()) + 
(matches[matches['result'] == 'W'][matches['venue'] == 'Away']['team'].value_counts())).sort_values().plot(kind='barh')
# Out:
# /var/folders/z9/yx7qb12d66s57rbmx2llg5d40000gn/T/ipykernel_50826/1664757187.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   ((matches[matches['result'] == 'W'][matches['venue'] == 'Home']['team'].value_counts()) +
# /var/folders/z9/yx7qb12d66s57rbmx2llg5d40000gn/T/ipykernel_50826/1664757187.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   (matches[matches['result'] == 'W'][matches['venue'] == 'Away']['team'].value_counts())).sort_values().plot(kind='barh')
# <AxesSubplot: >

# %%
#Horizontal Bar graph that calculates total losses both home and away by each team 

((matches[matches['result'] == 'L'][matches['venue'] == 'Home']['team'].value_counts()) + 
(matches[matches['result'] == 'L'][matches['venue'] == 'Away']['team'].value_counts())).sort_values().plot(kind='barh')
# Out:
# /var/folders/z9/yx7qb12d66s57rbmx2llg5d40000gn/T/ipykernel_50826/2092669573.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   ((matches[matches['result'] == 'L'][matches['venue'] == 'Home']['team'].value_counts()) +
# /var/folders/z9/yx7qb12d66s57rbmx2llg5d40000gn/T/ipykernel_50826/2092669573.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   (matches[matches['result'] == 'L'][matches['venue'] == 'Away']['team'].value_counts())).sort_values().plot(kind='barh')
# <AxesSubplot: >

# %%
#Adding total goals for 

matches.groupby('team')['gf'].sum().head()
# Out:
# team
# Arsenal                     94.0
# Aston Villa                 68.0
# Bournemouth                 18.0
# Brentford                   71.0
# Brighton and Hove Albion    65.0
# Name: gf, dtype: float64

# %%
((matches[matches['result'] == 'W'][matches['venue'] == 'Home']['team'].value_counts())).sort_values().plot(kind='bar')
# Out:
# /var/folders/z9/yx7qb12d66s57rbmx2llg5d40000gn/T/ipykernel_50826/2428732963.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   ((matches[matches['result'] == 'W'][matches['venue'] == 'Home']['team'].value_counts())).sort_values().plot(kind='bar')
# <AxesSubplot: >

# %%
matches.columns
# Out:
# Index(['Unnamed: 0', 'date', 'time', 'comp', 'round', 'day', 'venue', 'result',
#        'gf', 'ga', 'opponent', 'xg', 'xga', 'poss', 'attendance', 'captain',
#        'formation', 'referee', 'match report', 'notes', 'sh', 'sot', 'dist',
#        'fk', 'pk', 'pkatt', 'season', 'team'],
#       dtype='object')

# %%
mat = matches.reset_index(drop=True)

# %%
#Pie chart of w/ pct to show share of total home wins by each team 

((matches[matches['result'] == 'W'][matches['venue'] == 'Home']['team'].value_counts())).sort_values().plot(kind='pie', autopct='%1.1f%%')
# Out:
# /var/folders/z9/yx7qb12d66s57rbmx2llg5d40000gn/T/ipykernel_50826/3465864042.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   ((matches[matches['result'] == 'W'][matches['venue'] == 'Home']['team'].value_counts())).sort_values().plot(kind='pie', autopct='%1.1f%%')
# <AxesSubplot: ylabel='team'>

# %%
#Pie chart of w/ pct to show share of total wins by each team on Mondays 

((matches[matches['result'] == 'W'][matches['day'] == 'Mon']['team'].value_counts())).sort_values().plot(kind='pie', autopct='%1.1f%%')
# Out:
# /var/folders/z9/yx7qb12d66s57rbmx2llg5d40000gn/T/ipykernel_50826/3637918983.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   ((matches[matches['result'] == 'W'][matches['day'] == 'Mon']['team'].value_counts())).sort_values().plot(kind='pie', autopct='%1.1f%%')
# <AxesSubplot: ylabel='team'>

# %%
#Pie chart that shows gf for share percent in Arsenal overall wins 

((matches['gf'][matches['result'] == 'W'][matches['team'] == 'Arsenal'].value_counts())).sort_values().plot(kind='pie', autopct='%1.1f%%')
# Out:
# <AxesSubplot: ylabel='gf'>

# %%
#Calculating the average of goals scored overall 

round(matches.groupby('team')['gf'].mean())
# Out:
# team
# Arsenal                     1.81
# Aston Villa                 1.28
# Bournemouth                 1.20
# Brentford                   1.34
# Brighton and Hove Albion    1.25
# Burnley                     0.89
# Chelsea                     1.79
# Crystal Palace              1.25
# Everton                     1.02
# Fulham                      1.60
# Leeds United                1.23
# Leicester City              1.64
# Liverpool                   2.35
# Manchester City             2.67
# Manchester United           1.48
# Newcastle United            1.38
# Norwich City                0.61
# Nottingham Forest           0.73
# Southampton                 1.06
# Tottenham Hotspur           1.89
# Watford                     0.89
# West Ham United             1.36
# Wolverhampton Wanderers     0.87
# Name: gf, dtype: float64

# %%
#horizontal bar graph plotting overall average goals scored by each team.

matches.groupby('team')['gf'].mean().plot(kind='barh')
# Out:
# <AxesSubplot: ylabel='team'>
